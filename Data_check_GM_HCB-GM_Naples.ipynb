# %%
import pandas as pd

# Load and summarize the newly uploaded CSV files

# Path to the files
gm_fa_hcb_path =    'F:/Cursos/UOC Master Bio Inf. Est/M0.209 - UOC - TFM - Bio ML - Grafos/DATOS/MULTILAYER/DADES_HCB/GM_FA_HCB.csv'
gm_md_hcb_path =    'F:/Cursos/UOC Master Bio Inf. Est/M0.209 - UOC - TFM - Bio ML - Grafos/DATOS/MULTILAYER/DADES_HCB/GM_MD_HCB.csv'
gm_fa_naples_path = 'F:/Cursos/UOC Master Bio Inf. Est/M0.209 - UOC - TFM - Bio ML - Grafos/DATOS/MULTILAYER/DADES_NAPLES/GM_FA_NAPLES.csv'
gm_md_naples_path = 'F:/Cursos/UOC Master Bio Inf. Est/M0.209 - UOC - TFM - Bio ML - Grafos/DATOS/MULTILAYER/DADES_NAPLES/GM_MD_NAPLES.csv'

# Load CSV files
gm_fa_hcb_df = pd.read_csv(gm_fa_hcb_path,sep=' ')
gm_md_hcb_df = pd.read_csv(gm_md_hcb_path,sep=' ')
gm_fa_naples_df = pd.read_csv(gm_fa_naples_path,sep=' ',header=None)
gm_md_naples_df = pd.read_csv(gm_md_naples_path,sep=' ',header=None)

# This function checks for missing values in a DataFrame and displays the columns with missing values along with their percentage of missing data.
def missing_values_summary(df):
    """
    Displays columns with missing values and their percentage of missing data.
    """
    missing = df.isnull().mean() * 100
    missing = missing[missing > 0].sort_values(ascending=False)
    
    if missing.empty:
        print("✅ No missing values found in the DataFrame.")
    else:
        print("📌 Columns with missing values (%):\n")
        print(missing)
# Example usage:
# missing_values_summary(df)

# %% [markdown]
# # HCB

# %%
# Look for null values in the dataframe
missing_values_summary(gm_fa_hcb_df)

# Display datafre information
print("\n\n📌 HCB GM FA DataFrame Info:\n")
print(gm_fa_hcb_df.info())

#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Eliminate column with missing values
gm_fa_hcb_df.drop('Unnamed: 77', axis=1, inplace=True)

# Display the first few rows and basic information about each file
print("\n\n📌 HCB GM FA DataFrame head\n")
gm_fa_hcb_df.head()
# Out:
# 📌 Columns with missing values (%):
#
# Unnamed: 77    100.0
# dtype: float64
#
#
# 📌 HCB GM FA DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               178 non-null    object
#  1   ctx-lh-caudalanteriorcingulate   178 non-null    float64
#  2   ctx-lh-caudalmiddlefrontal       178 non-null    float64
#  3   ctx-lh-cuneus                    178 non-null    float64
#  4   ctx-lh-entorhinal                178 non-null    float64
#  5   ctx-lh-fusiform                  178 non-null    float64
#  6   ctx-lh-inferiorparietal          178 non-null    float64
#  7   ctx-lh-inferiortemporal          178 non-null    float64
#  8   ctx-lh-isthmuscingulate          178 non-null    float64
#  9   ctx-lh-lateraloccipital          178 non-null    float64
#  10  ctx-lh-lateralorbitofrontal      178 non-null    float64
#  11  ctx-lh-lingual                   178 non-null    float64
#  12  ctx-lh-medialorbitofrontal       178 non-null    float64
#  13  ctx-lh-middletemporal            178 non-null    float64
#  14  ctx-lh-parahippocampal           178 non-null    float64
#  15  ctx-lh-paracentral               178 non-null    float64
#  16  ctx-lh-parsopercularis           178 non-null    float64
#  17  ctx-lh-parsorbitalis             178 non-null    float64
#  18  ctx-lh-parstriangularis          178 non-null    float64
#  19  ctx-lh-pericalcarine             178 non-null    float64
#  20  ctx-lh-postcentral               178 non-null    float64
#  21  ctx-lh-posteriorcingulate        178 non-null    float64
#  22  ctx-lh-precentral                178 non-null    float64
#  23  ctx-lh-precuneus                 178 non-null    float64
#  24  ctx-lh-rostralanteriorcingulate  178 non-null    float64
#  25  ctx-lh-rostralmiddlefrontal      178 non-null    float64
#  26  ctx-lh-superiorfrontal           178 non-null    float64
#  27  ctx-lh-superiorparietal          178 non-null    float64
#  28  ctx-lh-superiortemporal          178 non-null    float64
#  29  ctx-lh-supramarginal             178 non-null    float64
#  30  ctx-lh-transversetemporal        178 non-null    float64
#  31  ctx-lh-insula                    178 non-null    float64
#  32  Left-Thalamus-Proper             178 non-null    float64
#  33  Left-Caudate                     178 non-null    float64
#  34  Left-Putamen                     178 non-null    float64
#  35  Left-Pallidum                    178 non-null    float64
#  36  Left-Hippocampus                 178 non-null    float64
#  37  Left-Amygdala                    178 non-null    float64
#  38  Left-Accumbens-area              178 non-null    float64
#  39  Right-Thalamus-Proper            178 non-null    float64
#  40  Right-Caudate                    178 non-null    float64
#  41  Right-Putamen                    178 non-null    float64
#  42  Right-Pallidum                   178 non-null    float64
#  43  Right-Hippocampus                178 non-null    float64
#  44  Right-Amygdala                   178 non-null    float64
#  45  Right-Accumbens-area             178 non-null    float64
#  46  ctx-rh-caudalanteriorcingulate   178 non-null    float64
#  47  ctx-rh-caudalmiddlefrontal       178 non-null    float64
#  48  ctx-rh-cuneus                    178 non-null    float64
#  49  ctx-rh-entorhinal                178 non-null    float64
#  50  ctx-rh-fusiform                  178 non-null    float64
#  51  ctx-rh-inferiorparietal          178 non-null    float64
#  52  ctx-rh-inferiortemporal          178 non-null    float64
#  53  ctx-rh-isthmuscingulate          178 non-null    float64
#  54  ctx-rh-lateraloccipital          178 non-null    float64
#  55  ctx-rh-lateralorbitofrontal      178 non-null    float64
#  56  ctx-rh-lingual                   178 non-null    float64
#  57  ctx-rh-medialorbitofrontal       178 non-null    float64
#  58  ctx-rh-middletemporal            178 non-null    float64
#  59  ctx-rh-parahippocampal           178 non-null    float64
#  60  ctx-rh-paracentral               178 non-null    float64
#  61  ctx-rh-parsopercularis           178 non-null    float64
#  62  ctx-rh-parsorbitalis             178 non-null    float64
#  63  ctx-rh-parstriangularis          178 non-null    float64
#  64  ctx-rh-pericalcarine             178 non-null    float64
#  65  ctx-rh-postcentral               178 non-null    float64
#  66  ctx-rh-posteriorcingulate        178 non-null    float64
#  67  ctx-rh-precentral                178 non-null    float64
#  68  ctx-rh-precuneus                 178 non-null    float64
#  69  ctx-rh-rostralanteriorcingulate  178 non-null    float64
#  70  ctx-rh-rostralmiddlefrontal      178 non-null    float64
#  71  ctx-rh-superiorfrontal           178 non-null    float64
#  72  ctx-rh-superiorparietal          178 non-null    float64
#  73  ctx-rh-superiortemporal          178 non-null    float64
#  74  ctx-rh-supramarginal             178 non-null    float64
#  75  ctx-rh-transversetemporal        178 non-null    float64
#  76  ctx-rh-insula                    178 non-null    float64
#  77  Unnamed: 77                      0 non-null      float64
# dtypes: float64(77), object(1)
# memory usage: 108.6+ KB
# None
#
#
# 📌 HCB GM FA DataFrame head
#          ID  ctx-lh-caudalanteriorcingulate  ctx-lh-caudalmiddlefrontal  \
# 0  002MSVIS                        0.154546                    0.105673
# 1  003MSVIS                        0.140591                    0.125810
# 2  004MSVIS                        0.130465                    0.127434
# 3  005MSVIS                        0.149958                    0.135914
# 4  010MSVIS                        0.142084                    0.120273
#
#    ctx-lh-cuneus  ctx-lh-entorhinal  ctx-lh-fusiform  ctx-lh-inferiorparietal  \
# 0       0.109286           0.113690         0.121950                 0.124290
# 1       0.108348           0.128998         0.144017                 0.120593
# 2       0.099488           0.106410         0.117190                 0.125902
# 3       0.110891           0.132164         0.130278                 0.114810
# 4       0.114463           0.126661         0.121473                 0.116001
#
#    ctx-lh-inferiortemporal  ctx-lh-isthmuscingulate  ctx-lh-lateraloccipital  \
# 0                 0.145755                 0.107960                 0.113971
# 1                 0.159399                 0.148756                 0.112457
# 2                 0.135107                 0.118033                 0.118602
# 3                 0.155775                 0.147337                 0.104433
# 4                 0.158306                 0.131609                 0.100061
#
#    ...  ctx-rh-precentral  ctx-rh-precuneus  ctx-rh-rostralanteriorcingulate  \
# 0  ...           0.113183          0.101905                         0.130367
# 1  ...           0.118461          0.118644                         0.142957
# 2  ...           0.115910          0.112950                         0.138247
# 3  ...           0.133075          0.119528                         0.142167
# 4  ...           0.124986          0.134653                         0.152228
#
#    ctx-rh-rostralmiddlefrontal  ctx-rh-superiorfrontal  \
# 0                     0.125799                0.127225
# 1                     0.131123                0.133418
# 2                     0.143105                0.140196
# 3                     0.143831                0.140334
# 4                     0.133456                0.134052
#
#    ctx-rh-superiorparietal  ctx-rh-superiortemporal  ctx-rh-supramarginal  \
# 0                 0.094132                 0.130378              0.103976
# 1                 0.110832                 0.137750              0.115864
# 2                 0.111843                 0.136728              0.126302
# 3                 0.116592                 0.133613              0.118032
# 4                 0.109802                 0.123276              0.126186
#
#    ctx-rh-transversetemporal  ctx-rh-insula
# 0                   0.100003       0.138035
# 1                   0.140126       0.166966
# 2                   0.131334       0.145249
# 3                   0.145744       0.152125
# 4                   0.131977       0.158511
#
# [5 rows x 77 columns]

# %%
# Look for null values in the dataframe
missing_values_summary(gm_md_hcb_df)

# Display datafre information
print("\n\n📌 HCB GM MD DataFrame Info:\n")
print(gm_md_hcb_df.info())

#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Eliminate column with missing values
gm_md_hcb_df.drop('Unnamed: 77', axis=1, inplace=True)

# Display the first few rows and basic information about each file
print("\n\n📌 HCB GM MD DataFrame head\n")
gm_md_hcb_df.head()
# Out:
# 📌 Columns with missing values (%):
#
# Unnamed: 77    100.0
# dtype: float64
#
#
# 📌 HCB GM MD DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               178 non-null    object
#  1   ctx-lh-caudalanteriorcingulate   178 non-null    float64
#  2   ctx-lh-caudalmiddlefrontal       178 non-null    float64
#  3   ctx-lh-cuneus                    178 non-null    float64
#  4   ctx-lh-entorhinal                178 non-null    float64
#  5   ctx-lh-fusiform                  178 non-null    float64
#  6   ctx-lh-inferiorparietal          178 non-null    float64
#  7   ctx-lh-inferiortemporal          178 non-null    float64
#  8   ctx-lh-isthmuscingulate          178 non-null    float64
#  9   ctx-lh-lateraloccipital          178 non-null    float64
#  10  ctx-lh-lateralorbitofrontal      178 non-null    float64
#  11  ctx-lh-lingual                   178 non-null    float64
#  12  ctx-lh-medialorbitofrontal       178 non-null    float64
#  13  ctx-lh-middletemporal            178 non-null    float64
#  14  ctx-lh-parahippocampal           178 non-null    float64
#  15  ctx-lh-paracentral               178 non-null    float64
#  16  ctx-lh-parsopercularis           178 non-null    float64
#  17  ctx-lh-parsorbitalis             178 non-null    float64
#  18  ctx-lh-parstriangularis          178 non-null    float64
#  19  ctx-lh-pericalcarine             178 non-null    float64
#  20  ctx-lh-postcentral               178 non-null    float64
#  21  ctx-lh-posteriorcingulate        178 non-null    float64
#  22  ctx-lh-precentral                178 non-null    float64
#  23  ctx-lh-precuneus                 178 non-null    float64
#  24  ctx-lh-rostralanteriorcingulate  178 non-null    float64
#  25  ctx-lh-rostralmiddlefrontal      178 non-null    float64
#  26  ctx-lh-superiorfrontal           178 non-null    float64
#  27  ctx-lh-superiorparietal          178 non-null    float64
#  28  ctx-lh-superiortemporal          178 non-null    float64
#  29  ctx-lh-supramarginal             178 non-null    float64
#  30  ctx-lh-transversetemporal        178 non-null    float64
#  31  ctx-lh-insula                    178 non-null    float64
#  32  Left-Thalamus-Proper             178 non-null    float64
#  33  Left-Caudate                     178 non-null    float64
#  34  Left-Putamen                     178 non-null    float64
#  35  Left-Pallidum                    178 non-null    float64
#  36  Left-Hippocampus                 178 non-null    float64
#  37  Left-Amygdala                    178 non-null    float64
#  38  Left-Accumbens-area              178 non-null    float64
#  39  Right-Thalamus-Proper            178 non-null    float64
#  40  Right-Caudate                    178 non-null    float64
#  41  Right-Putamen                    178 non-null    float64
#  42  Right-Pallidum                   178 non-null    float64
#  43  Right-Hippocampus                178 non-null    float64
#  44  Right-Amygdala                   178 non-null    float64
#  45  Right-Accumbens-area             178 non-null    float64
#  46  ctx-rh-caudalanteriorcingulate   178 non-null    float64
#  47  ctx-rh-caudalmiddlefrontal       178 non-null    float64
#  48  ctx-rh-cuneus                    178 non-null    float64
#  49  ctx-rh-entorhinal                178 non-null    float64
#  50  ctx-rh-fusiform                  178 non-null    float64
#  51  ctx-rh-inferiorparietal          178 non-null    float64
#  52  ctx-rh-inferiortemporal          178 non-null    float64
#  53  ctx-rh-isthmuscingulate          178 non-null    float64
#  54  ctx-rh-lateraloccipital          178 non-null    float64
#  55  ctx-rh-lateralorbitofrontal      178 non-null    float64
#  56  ctx-rh-lingual                   178 non-null    float64
#  57  ctx-rh-medialorbitofrontal       178 non-null    float64
#  58  ctx-rh-middletemporal            178 non-null    float64
#  59  ctx-rh-parahippocampal           178 non-null    float64
#  60  ctx-rh-paracentral               178 non-null    float64
#  61  ctx-rh-parsopercularis           178 non-null    float64
#  62  ctx-rh-parsorbitalis             178 non-null    float64
#  63  ctx-rh-parstriangularis          178 non-null    float64
#  64  ctx-rh-pericalcarine             178 non-null    float64
#  65  ctx-rh-postcentral               178 non-null    float64
#  66  ctx-rh-posteriorcingulate        178 non-null    float64
#  67  ctx-rh-precentral                178 non-null    float64
#  68  ctx-rh-precuneus                 178 non-null    float64
#  69  ctx-rh-rostralanteriorcingulate  178 non-null    float64
#  70  ctx-rh-rostralmiddlefrontal      178 non-null    float64
#  71  ctx-rh-superiorfrontal           178 non-null    float64
#  72  ctx-rh-superiorparietal          178 non-null    float64
#  73  ctx-rh-superiortemporal          178 non-null    float64
#  74  ctx-rh-supramarginal             178 non-null    float64
#  75  ctx-rh-transversetemporal        178 non-null    float64
#  76  ctx-rh-insula                    178 non-null    float64
#  77  Unnamed: 77                      0 non-null      float64
# dtypes: float64(77), object(1)
# memory usage: 108.6+ KB
# None
#
#
# 📌 HCB GM MD DataFrame head
#          ID  ctx-lh-caudalanteriorcingulate  ctx-lh-caudalmiddlefrontal  \
# 0  002MSVIS                        0.000891                    0.001008
# 1  003MSVIS                        0.000899                    0.001021
# 2  004MSVIS                        0.000901                    0.001052
# 3  005MSVIS                        0.000878                    0.000983
# 4  010MSVIS                        0.000887                    0.000998
#
#    ctx-lh-cuneus  ctx-lh-entorhinal  ctx-lh-fusiform  ctx-lh-inferiorparietal  \
# 0       0.001059           0.001042         0.000926                 0.000963
# 1       0.001048           0.000958         0.000831                 0.000918
# 2       0.001256           0.001026         0.000934                 0.001014
# 3       0.001040           0.001105         0.000884                 0.000966
# 4       0.001175           0.001071         0.000916                 0.000989
#
#    ctx-lh-inferiortemporal  ctx-lh-isthmuscingulate  ctx-lh-lateraloccipital  \
# 0                 0.000873                 0.001076                 0.000932
# 1                 0.000846                 0.000867                 0.000943
# 2                 0.000891                 0.001001                 0.001064
# 3                 0.000911                 0.000955                 0.000915
# 4                 0.000958                 0.000924                 0.001089
#
#    ...  ctx-rh-precentral  ctx-rh-precuneus  ctx-rh-rostralanteriorcingulate  \
# 0  ...           0.001123          0.001067                         0.000962
# 1  ...           0.001012          0.000934                         0.000858
# 2  ...           0.001148          0.001075                         0.000846
# 3  ...           0.001045          0.001017                         0.000841
# 4  ...           0.001051          0.001040                         0.000863
#
#    ctx-rh-rostralmiddlefrontal  ctx-rh-superiorfrontal  \
# 0                     0.000981                0.000971
# 1                     0.000954                0.000953
# 2                     0.000964                0.000965
# 3                     0.000982                0.000950
# 4                     0.000938                0.000960
#
#    ctx-rh-superiorparietal  ctx-rh-superiortemporal  ctx-rh-supramarginal  \
# 0                 0.001176                 0.000998              0.001177
# 1                 0.000987                 0.000882              0.000958
# 2                 0.001169                 0.000949              0.001005
# 3                 0.001114                 0.000914              0.001016
# 4                 0.001123                 0.000916              0.000959
#
#    ctx-rh-transversetemporal  ctx-rh-insula
# 0                   0.001391       0.000970
# 1                   0.000970       0.000851
# 2                   0.000952       0.000907
# 3                   0.000952       0.000896
# 4                   0.000915       0.000906
#
# [5 rows x 77 columns]

# %% [markdown]
# # Naples

# %%
# Look for null values in the dataframe
missing_values_summary(gm_fa_naples_df)

# Display datafre information
print("\n\n📌 Naples FA GM DataFrame Info:\n")
print(gm_fa_naples_df.info())

#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Eliminate column with missing values
gm_fa_naples_df.drop(77, axis=1, inplace=True)

# Display the first few rows and basic information about each file
print("\n\n📌 Naples FA GM DataFrame head\n")
gm_fa_naples_df.head()
# Out:
# 📌 Columns with missing values (%):
#
# 77    100.0
# dtype: float64
#
#
# 📌 Naples FA GM DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 78 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       105 non-null    object
#  1   1       105 non-null    float64
#  2   2       105 non-null    float64
#  3   3       105 non-null    float64
#  4   4       105 non-null    float64
#  5   5       105 non-null    float64
#  6   6       105 non-null    float64
#  7   7       105 non-null    float64
#  8   8       105 non-null    float64
#  9   9       105 non-null    float64
#  10  10      105 non-null    float64
#  11  11      105 non-null    float64
#  12  12      105 non-null    float64
#  13  13      105 non-null    float64
#  14  14      105 non-null    float64
#  15  15      105 non-null    float64
#  16  16      105 non-null    float64
#  17  17      105 non-null    float64
#  18  18      105 non-null    float64
#  19  19      105 non-null    float64
#  20  20      105 non-null    float64
#  21  21      105 non-null    float64
#  22  22      105 non-null    float64
#  23  23      105 non-null    float64
#  24  24      105 non-null    float64
#  25  25      105 non-null    float64
#  26  26      105 non-null    float64
#  27  27      105 non-null    float64
#  28  28      105 non-null    float64
#  29  29      105 non-null    float64
#  30  30      105 non-null    float64
#  31  31      105 non-null    float64
#  32  32      105 non-null    float64
#  33  33      105 non-null    float64
#  34  34      105 non-null    float64
#  35  35      105 non-null    float64
#  36  36      105 non-null    float64
#  37  37      105 non-null    float64
#  38  38      105 non-null    float64
#  39  39      105 non-null    float64
#  40  40      105 non-null    float64
#  41  41      105 non-null    float64
#  42  42      105 non-null    float64
#  43  43      105 non-null    float64
#  44  44      105 non-null    float64
#  45  45      105 non-null    float64
#  46  46      105 non-null    float64
#  47  47      105 non-null    float64
#  48  48      105 non-null    float64
#  49  49      105 non-null    float64
#  50  50      105 non-null    float64
#  51  51      105 non-null    float64
#  52  52      105 non-null    float64
#  53  53      105 non-null    float64
#  54  54      105 non-null    float64
#  55  55      105 non-null    float64
#  56  56      105 non-null    float64
#  57  57      105 non-null    float64
#  58  58      105 non-null    float64
#  59  59      105 non-null    float64
#  60  60      105 non-null    float64
#  61  61      105 non-null    float64
#  62  62      105 non-null    float64
#  63  63      105 non-null    float64
#  64  64      105 non-null    float64
#  65  65      105 non-null    float64
#  66  66      105 non-null    float64
#  67  67      105 non-null    float64
#  68  68      105 non-null    float64
#  69  69      105 non-null    float64
#  70  70      105 non-null    float64
#  71  71      105 non-null    float64
#  72  72      105 non-null    float64
#  73  73      105 non-null    float64
#  74  74      105 non-null    float64
#  75  75      105 non-null    float64
#  76  76      105 non-null    float64
#  77  77      0 non-null      float64
# dtypes: float64(77), object(1)
# memory usage: 64.1+ KB
# None
#
#
# 📌 Naples FA GM DataFrame head
#          0         1         2         3         4         5         6   \
# 0  sub-0001  0.126030  0.155114  0.075599  0.122521  0.130541  0.106313
# 1  sub-0002  0.137124  0.129887  0.080547  0.130638  0.113284  0.105551
# 2  sub-0003  0.109621  0.107655  0.089298  0.126033  0.116021  0.095920
# 3  sub-0004  0.124650  0.118367  0.087348  0.140727  0.122936  0.114695
# 4  sub-0005  0.143922  0.130091  0.100755  0.148164  0.125079  0.108867
#
#          7         8         9   ...        67        68        69        70  \
# 0  0.142900  0.135765  0.091170  ...  0.142996  0.123127  0.110973  0.151969
# 1  0.139676  0.116486  0.082512  ...  0.120405  0.112286  0.129320  0.124577
# 2  0.135421  0.112577  0.088280  ...  0.116394  0.114698  0.117400  0.127499
# 3  0.130150  0.144920  0.094023  ...  0.113848  0.127827  0.147713  0.121296
# 4  0.158107  0.135797  0.080383  ...  0.145844  0.138359  0.129947  0.133843
#
#          71        72        73        74        75        76
# 0  0.160402  0.114224  0.125014  0.137323  0.112845  0.139207
# 1  0.142509  0.112583  0.125164  0.119006  0.122426  0.134654
# 2  0.134893  0.114820  0.120377  0.109135  0.117805  0.117330
# 3  0.135143  0.127516  0.128140  0.108645  0.135168  0.148403
# 4  0.153386  0.124243  0.125194  0.124122  0.114987  0.147867
#
# [5 rows x 77 columns]

# %%
# Look for null values in the dataframe
missing_values_summary(gm_md_naples_df)

# Display datafre information
print("\n\n📌 Naples GM MD DataFrame Info:\n")
print(gm_md_naples_df.info())

#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Eliminate column with missing values
gm_md_naples_df.drop(77, axis=1, inplace=True)

# Display the first few rows and basic information about each file
print("\n\n📌 Naples GM MD  DataFrame head\n")
gm_md_naples_df.head()
# Out:
# 📌 Columns with missing values (%):
#
# 77    100.0
# dtype: float64
#
#
# 📌 Naples GM MD DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 78 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       105 non-null    object
#  1   1       105 non-null    float64
#  2   2       105 non-null    float64
#  3   3       105 non-null    float64
#  4   4       105 non-null    float64
#  5   5       105 non-null    float64
#  6   6       105 non-null    float64
#  7   7       105 non-null    float64
#  8   8       105 non-null    float64
#  9   9       105 non-null    float64
#  10  10      105 non-null    float64
#  11  11      105 non-null    float64
#  12  12      105 non-null    float64
#  13  13      105 non-null    float64
#  14  14      105 non-null    float64
#  15  15      105 non-null    float64
#  16  16      105 non-null    float64
#  17  17      105 non-null    float64
#  18  18      105 non-null    float64
#  19  19      105 non-null    float64
#  20  20      105 non-null    float64
#  21  21      105 non-null    float64
#  22  22      105 non-null    float64
#  23  23      105 non-null    float64
#  24  24      105 non-null    float64
#  25  25      105 non-null    float64
#  26  26      105 non-null    float64
#  27  27      105 non-null    float64
#  28  28      105 non-null    float64
#  29  29      105 non-null    float64
#  30  30      105 non-null    float64
#  31  31      105 non-null    float64
#  32  32      105 non-null    float64
#  33  33      105 non-null    float64
#  34  34      105 non-null    float64
#  35  35      105 non-null    float64
#  36  36      105 non-null    float64
#  37  37      105 non-null    float64
#  38  38      105 non-null    float64
#  39  39      105 non-null    float64
#  40  40      105 non-null    float64
#  41  41      105 non-null    float64
#  42  42      105 non-null    float64
#  43  43      105 non-null    float64
#  44  44      105 non-null    float64
#  45  45      105 non-null    float64
#  46  46      105 non-null    float64
#  47  47      105 non-null    float64
#  48  48      105 non-null    float64
#  49  49      105 non-null    float64
#  50  50      105 non-null    float64
#  51  51      105 non-null    float64
#  52  52      105 non-null    float64
#  53  53      105 non-null    float64
#  54  54      105 non-null    float64
#  55  55      105 non-null    float64
#  56  56      105 non-null    float64
#  57  57      105 non-null    float64
#  58  58      105 non-null    float64
#  59  59      105 non-null    float64
#  60  60      105 non-null    float64
#  61  61      105 non-null    float64
#  62  62      105 non-null    float64
#  63  63      105 non-null    float64
#  64  64      105 non-null    float64
#  65  65      105 non-null    float64
#  66  66      105 non-null    float64
#  67  67      105 non-null    float64
#  68  68      105 non-null    float64
#  69  69      105 non-null    float64
#  70  70      105 non-null    float64
#  71  71      105 non-null    float64
#  72  72      105 non-null    float64
#  73  73      105 non-null    float64
#  74  74      105 non-null    float64
#  75  75      105 non-null    float64
#  76  76      105 non-null    float64
#  77  77      0 non-null      float64
# dtypes: float64(77), object(1)
# memory usage: 64.1+ KB
# None
#
#
# 📌 Naples GM MD  DataFrame head
#          0         1         2         3         4         5         6   \
# 0  sub-0001  0.000856  0.000869  0.001171  0.001000  0.000911  0.001004
# 1  sub-0002  0.000884  0.000946  0.001168  0.001089  0.000940  0.001010
# 2  sub-0003  0.000885  0.000868  0.001011  0.001056  0.000830  0.000923
# 3  sub-0004  0.000923  0.000919  0.001082  0.001014  0.000891  0.000933
# 4  sub-0005  0.000846  0.000868  0.001103  0.001085  0.000850  0.000976
#
#          7         8         9   ...        67        68        69        70  \
# 0  0.000963  0.001025  0.001038  ...  0.001046  0.001061  0.000933  0.000883
# 1  0.000936  0.001083  0.001037  ...  0.001037  0.001065  0.000999  0.000927
# 2  0.000808  0.000932  0.000930  ...  0.000919  0.000955  0.000840  0.000838
# 3  0.000906  0.001050  0.000955  ...  0.000977  0.001061  0.000822  0.000954
# 4  0.000848  0.000970  0.000983  ...  0.000900  0.000998  0.000884  0.000846
#
#          71        72        73        74        75        76
# 0  0.000925  0.001153  0.000930  0.000967  0.001082  0.000900
# 1  0.000905  0.000972  0.000909  0.000969  0.001000  0.000957
# 2  0.000845  0.000961  0.000855  0.000880  0.000878  0.000910
# 3  0.000901  0.001022  0.000886  0.000896  0.000925  0.000908
# 4  0.000822  0.001023  0.000875  0.000911  0.000975  0.000884
#
# [5 rows x 77 columns]

# %% [markdown]
# # Saving and loading DFs as pkl files

# %%
def save_dataframe(df, filename, file_format='pkl'):
    """
    Save a pandas DataFrame in the desired format.

    Parameters:
    - df: pandas DataFrame
    - filename: name of the output file (without extension)
    - file_format: 'pkl', 'csv', 'parquet', or 'feather' (default: 'pkl')
    """
    if file_format == 'pkl':
        df.to_pickle(f"{filename}.pkl")
        print(f"✅ DataFrame saved as {filename}.pkl")
    elif file_format == 'csv':
        df.to_csv(f"{filename}.csv", index=False)
        print(f"✅ DataFrame saved as {filename}.csv")
    elif file_format == 'parquet':
        df.to_parquet(f"{filename}.parquet")
        print(f"✅ DataFrame saved as {filename}.parquet")
    elif file_format == 'feather':
        df.to_feather(f"{filename}.feather")
        print(f"✅ DataFrame saved as {filename}.feather")
    else:
        print("❌ Unsupported file format. Choose 'pkl', 'csv', 'parquet', or 'feather'.")

# Example usage:
# save_dataframe(clinic_hcb_df, 'clinic_data', file_format='parquet')

from pathlib import Path

ruta_naples = Path('F:/Cursos/UOC Master Bio Inf. Est/M0.209 - UOC - TFM - Bio ML - Grafos/DATOS/MULTILAYER/DADES_NAPLES') 
ruta_hcb = Path('F:/Cursos/UOC Master Bio Inf. Est/M0.209 - UOC - TFM - Bio ML - Grafos/DATOS/MULTILAYER/DADES_HCB') 

# Save
save_dataframe(gm_fa_naples_df, ruta_naples / 'GM_FA_NAPLES', file_format='pkl')
save_dataframe(gm_md_naples_df, ruta_naples / 'GM_MD_NAPLES', file_format='pkl')
save_dataframe(gm_fa_hcb_df, ruta_hcb / 'GM_FA_HCB', file_format='pkl')
save_dataframe(gm_md_hcb_df, ruta_hcb / 'GM_MD_HCB', file_format='pkl')
# Out:
# ✅ DataFrame saved as F:\Cursos\UOC Master Bio Inf. Est\M0.209 - UOC - TFM - Bio ML - Grafos\DATOS\MULTILAYER\DADES_NAPLES\GM_FA_NAPLES.pkl
# ✅ DataFrame saved as F:\Cursos\UOC Master Bio Inf. Est\M0.209 - UOC - TFM - Bio ML - Grafos\DATOS\MULTILAYER\DADES_NAPLES\GM_MD_NAPLES.pkl
# ✅ DataFrame saved as F:\Cursos\UOC Master Bio Inf. Est\M0.209 - UOC - TFM - Bio ML - Grafos\DATOS\MULTILAYER\DADES_HCB\GM_FA_HCB.pkl
# ✅ DataFrame saved as F:\Cursos\UOC Master Bio Inf. Est\M0.209 - UOC - TFM - Bio ML - Grafos\DATOS\MULTILAYER\DADES_HCB\GM_MD_HCB.pkl

# %%
def load_dataframe(filepath):
    """
    Load a pandas DataFrame from a file, inferring the format by extension.

    Parameters:
    - filepath: full path to the file (with extension)

    Returns:
    - pandas DataFrame
    """
    if str(filepath).endswith('.pkl'):
        df = pd.read_pickle(filepath)
    elif str(filepath).endswith('.csv'):
        df = pd.read_csv(filepath)
    elif str(filepath).endswith('.parquet'):
        df = pd.read_parquet(filepath)
    elif str(filepath).endswith('.feather'):
        df = pd.read_feather(filepath)
    else:
        raise ValueError("❌ Unsupported file format. Supported formats: .pkl, .csv, .parquet, .feather")
    
    print(f"✅ DataFrame loaded from {filepath}")
    return df
# Example usage:
# df_loaded = load_dataframe(rute / 'clinic_data.parquet')


# Load the saved DataFrames
df_loaded_GM_FA_NAPLES = load_dataframe(ruta_naples / 'GM_FA_NAPLES.pkl')
df_loaded_GM_MD_NAPLES = load_dataframe(ruta_naples / 'GM_MD_NAPLES.pkl')
df_loaded_GM_FA_HCB = load_dataframe(ruta_hcb / 'GM_FA_HCB.pkl')
df_loaded_GM_MD_HCB = load_dataframe(ruta_hcb / 'GM_MD_HCB.pkl')
# Out:
# ✅ DataFrame loaded from F:\Cursos\UOC Master Bio Inf. Est\M0.209 - UOC - TFM - Bio ML - Grafos\DATOS\MULTILAYER\DADES_NAPLES\GM_FA_NAPLES.pkl
# ✅ DataFrame loaded from F:\Cursos\UOC Master Bio Inf. Est\M0.209 - UOC - TFM - Bio ML - Grafos\DATOS\MULTILAYER\DADES_NAPLES\GM_MD_NAPLES.pkl
# ✅ DataFrame loaded from F:\Cursos\UOC Master Bio Inf. Est\M0.209 - UOC - TFM - Bio ML - Grafos\DATOS\MULTILAYER\DADES_HCB\GM_FA_HCB.pkl
# ✅ DataFrame loaded from F:\Cursos\UOC Master Bio Inf. Est\M0.209 - UOC - TFM - Bio ML - Grafos\DATOS\MULTILAYER\DADES_HCB\GM_MD_HCB.pkl
